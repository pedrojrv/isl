# %% [markdown]
# # Applied Q&A

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## 8.
#
# This exercise relates to the College data set, which can be found in the file College.csv on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are
#
# - Private : Public/private indicator
# - Apps : Number of applications received
# - Accept : Number of applicants accepted
# - Enroll : Number of new students enrolled
# - Top10perc : New students from top 10 % of high school class
# - Top25perc : New students from top 25 % of high school class
# - F.Undergrad : Number of full-time undergraduates
# - P.Undergrad : Number of part-time undergraduates
# - Outstate : Out-of-state tuition
# - Room.Board : Room and board costs
# - Books : Estimated book costs
# - Personal : Estimated personal spending
# - PhD : Percent of faculty with Ph.D.’s
# - Terminal : Percent of faculty with terminal degree
# - S.F.Ratio : Student/faculty ratio
# - perc.alumni : Percent of alumni who donate
# - Expend : Instructional expenditure per student
# - Grad.Rate : Graduation rate
#
#
# Before reading the data into R, it can be viewed in Excel or a text editor.
#
# - (a) Use the read.csv() function to read the data into R. Call the loaded data college. Make sure that you have the directory set to the correct location for the data.

# %%
college_data_path = "../data/College.csv"
college_df = pd.read_csv(college_data_path, index_col=0)

# %% [markdown]
# - b) Look at the data using the View() function. You should notice that the first column is just the name of each university. We don’t really want R to treat this as data. However, it may be handy to have these names for later. Try the following commands:
#
# ```r
# > rownames(college) <- college[, 1]
# > View(college)
# ```
# You should see that there is now a row.names column with the name of each university recorded. This means that R has given each row a name corresponding to the appropriate university. R will not try to perform calculations on the row names. However, we still need to eliminate the first column in the data where the names are stored. Try
#
# ```r
# > college <- college[, -1]
# > View(college)
# ```
#
# Now you should see that the first data column is Private. Note that another column labeled row.names now appears before the Private column. However, this is not a data column but rather the name that R is giving to each row.

# %%
college_df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# - ci. Use the summary() function to produce a numerical summary of the variables in the data set.

# %%
college_df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# - cii. Use the pairs() function to produce a scatterplot matrix of the first ten columns or variables of the data. Recall that you can reference the first ten columns of a matrix A using A[,1:10].

# %%
_ = pd.plotting.scatter_matrix(college_df.iloc[:, :5], alpha=0.2, figsize=(20, 10))

# %% [markdown]
# - ciii. Use the plot() function to produce side-by-side boxplots of Outstate versus Private.

# %%
ax = sns.boxplot(y="Outstate", x='Private', hue="Private", data=college_df, palette="Set3")

# %% [markdown]
# - civ. Create a new qualitative variable, called Elite, by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50 %.
#
# ```r
# > Elite <- rep("No", nrow(college))
# > Elite[college$Top10perc > 50] <- "Yes" > Elite <- as.factor(Elite)
# > college <- data.frame(college, Elite)
# ```
#
# Use the summary() function to see how many elite universities there are. Now use the plot() function to produce side-by-side boxplots of Outstate versus Elite.

# %%
college_df['Elite'] = college_df['Top10perc'].apply(lambda x: 1 if x >= 50 else 0)

# %%
college_df.Elite.value_counts()
# Out:
# 0    694
# 1     83
# Name: Elite, dtype: int64

# %%
ax = sns.boxplot(y="Outstate", x='Elite', hue="Elite", data=college_df, palette="Set3")

# %% [markdown]
# - cv. Use the hist() function to produce some histograms with differing numbers of bins for a few of the quantitative variables. You may find the command par(mfrow = c(2, 2)) useful: it will divide the print window into four regions so that four plots can be made simultaneously. Modifying the arguments to this function will divide the screen in other ways.

# %%
_ = college_df[['Apps', 'Accept', 'Enroll']].hist(layout=(1, 3), figsize=(15, 5), bins=100)

# %% [markdown]
# - cvi. Continue exploring the data, and provide a brief summary of what you discover.
#
# Private universities charge more for out of state students and are also home to the higher number of top 10% students.

# %% [markdown]
# ## 9.
#
# This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
auto_df = pd.read_csv("../data/Auto.csv")
auto_df['origin'] = auto_df.origin.astype(str)

# %%
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#   origin                       name
# 0      1  chevrolet chevelle malibu
# 1      1          buick skylark 320
# 2      1         plymouth satellite
# 3      1              amc rebel sst
# 4      1                ford torino

# %% [markdown]
# - a) Which of the predictors are quantitative, and which are qualitative?
#
#   - Quantitative:
#     - mpg: miles per gallon, quantitative
#     - cylinders: number of cylinders, quantitative
#     - horsepower: quantitative
#     - weight: weight of vehicle, quantitative
#     - acceleration: how fast does the vehicle accelerates, quantitative
#     - year: release year, quantitative
#
#
#   - Qualitative:
#     - origin: appears to be the origin of the vehicle from three values, qualitative
#     - name: name of the car, qualitative

# %% [markdown]
# - b) What is the range of each quantitative predictor? You can answer this using the range() function.
#
# - c) What is the mean and standard deviation of each quantitative predictor?
#
# We can answer both of these questions with `.describe()`.

# %%
# .describe() provides not only the range (min, max) but also other useful statistics.
auto_df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year
# count  397.000000
# mean    75.994962
# std      3.690005
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %% [markdown]
# d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
subset_auto_df = auto_df[~auto_df.index.isin(range(9, 86))]
subset_auto_df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  320.000000  320.000000    320.000000   320.000000    320.000000
# mean    24.474375    5.362500    186.540625  2930.318750     15.731563
# std      7.894554    1.649499     99.372190   809.275266      2.680366
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000     99.500000  2213.750000     14.000000
# 50%     23.950000    4.000000    144.500000  2792.500000     15.550000
# 75%     30.750000    6.000000    250.000000  3474.750000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year
# count  320.000000
# mean    77.165625
# std      3.107389
# min     70.000000
# 25%     75.000000
# 50%     77.000000
# 75%     80.000000
# max     82.000000

# %% [markdown]
# e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.
#
# `mpg` appears to be lower for 8-cylinder vehicles than for lower cylinder autos. Same story with displacement and weight. Higher displacement and heavier vehicles both have very similar distributions when plotted against `mpg`. `Heavier vehicles are also associated with higher displacements. This is probably due to bigger vehicles having heavier and bigger engines which allow for more displacement. There appear to be a slight trend when comparing mpg with year (mpg getting better thorugout the years).

# %%
_ = pd.plotting.scatter_matrix(auto_df, alpha=0.2, figsize=(20, 10))

# %% [markdown]
# f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.
#
# The answer above explains this. There appears to be a significant correlation with cylinders, displacement, weight, and year. Not that noticable with acceleration. Cars from `origin=3` appear to have better vehicles in terms of `mpg`.

# %%
ax = sns.boxplot(y="mpg", x='origin', hue="origin", data=auto_df, palette="Set3")

# %% [markdown]
# ## 10.
#
# This exercise involves the Boston housing data set.
#
# (a) To begin, load in the Boston data set. The Boston data set is part of the ISLR2 library.
#
# ```r
# > library(ISLR2)
# ```
#
# Now the data set is contained in the object Boston.
#
# ```r
# > Boston
# ```
#
# Read about the data set:
#
# ```r
# > ?Boston
# ```
#
# How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
housing_df = pd.read_csv("../data/Boston.csv", index_col=0)
housing_df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 1   4.98  24.0
# 2   9.14  21.6
# 3   4.03  34.7
# 4   2.94  33.4
# 5   5.33  36.2

# %% [markdown]
# b) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
_ = pd.plotting.scatter_matrix(housing_df, alpha=0.2, figsize=(20, 10))

# %% [markdown]
# (c) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.
#
# It appears `zn`, `indus`, `nox`, `rm`, `age`, `dis`, `rad`, `tax`, `ptratio`, `lstat`, `medv` appear to have from slight to high correlation.

# %%
housing_df.corr()['crim']
# Out:
# crim       1.000000
# zn        -0.200469
# indus      0.406583
# chas      -0.055892
# nox        0.420972
# rm        -0.219247
# age        0.352734
# dis       -0.379670
# rad        0.625505
# tax        0.582764
# ptratio    0.289946
# lstat      0.455621
# medv      -0.388305
# Name: crim, dtype: float64

# %% [markdown]
# (d) Do any of the census tracts of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.
#
# Not sure what is the meaning of each column and can't find the description.

# %%
housing_df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# (e) How many of the census tracts in this data set bound the Charles river?
#
# Not sure which columns are geographic location related.
#
# (f) What is the median pupil-teacher ratio among the towns in this data set?

# %%
housing_df['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# (g) Which census tract of Boston has lowest median value of owner-occupied homes? What are the values of the other predictors for that census tract, and how do those values compare to
# the overall ranges for those predictors? Comment on your findings.
#
# The zones with the lowest median value have some of the highest crime rates and the highest pupil-to-teach reation.

# %%
# Assuming `medv` stands for median value 
housing_df[housing_df.medv == housing_df.medv.min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 399     20.2  30.59   5.0
# 406     20.2  22.98   5.0

# %% [markdown]
# (h) In this data set, how many of the census tracts average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the census tracts that average more than eight rooms per dwelling.
